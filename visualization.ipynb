# %%
import seaborn as sns
import pandas as pd

# %%
movies = pd.read_csv('P4-Movie-Ratings.csv')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRatings',
       'BudgetMillion', 'YearOfRelease']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  YearOfRelease
# 0              8           2009
# 1            105           2008
# 2             20           2009
# 3             18           2010
# 4             20           2009

# %%
splot = sns.scatterplot(data=movies, x='CriticRating',y='AudienceRatings')

# %%
movies.info
# Out:
# <bound method DataFrame.info of                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillion  YearOfRelease
# 0                8           2009
# 1              105           2008
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   YearOfRelease    559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   YearOfRelease    559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.YearOfRelease = movies.YearOfRelease.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   YearOfRelease    559 non-null    category
# dtypes: category(2), int64(3), object(1)
# memory usage: 40.0+ KB

# %%
movies.Genre= movies.Genre.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   YearOfRelease    559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
j=sns.jointplot(data=movies, x='CriticRating',y='AudienceRatings',kind='hex')

# %%
sns.displot(movies.CriticRating)

# %%
sns.displot(movies.AudienceRatings)

# %%
sns.set_style('darkgrid')
sns.displot(movies.AudienceRatings)

# %%
import matplotlib.pyplot as plt
plt.hist(movies.CriticRating)
# Out:
# (array([38., 64., 75., 53., 68., 64., 43., 54., 57., 43.]),
#  array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'BudgetMillion',
#        'YearOfRelease'],
#       dtype='object')

# %%
plt.hist(movies.BudgetMillion)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genre==''].BudgetMillion)

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(movies[movies.Genre=='Comedy'].BudgetMillion)
plt.hist(movies[movies.Genre=='Action'].BudgetMillion)
plt.hist(movies[movies.Genre=='Horror'].BudgetMillion)
plt.show()

# %%
l1 =[movies[movies.Genre=='Comedy'].BudgetMillion,movies[movies.Genre=='Action'].BudgetMillion,movies[movies.Genre=='Horror'].BudgetMillion]
mylabels =['Comedy','Action','Horror']

# %%
plt.hist(l1,stacked=True,label=mylabels)
plt.legend()
plt.show()
